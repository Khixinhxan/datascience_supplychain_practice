# %%
import pandas as pd
import inventorize as inv
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
import os
path  = os.getcwd()
print(path)
# Out:
# /Users/dang/Desktop/Learning/Mygit/datascience_supplychain_practice/Jupyternotebook_source/Section_21_multi_product_optimization

# %%
multi = pd.read_csv("{0}/multvariate_slides.csv".format(path))

# %%
multi.iloc[:,1:5].describe()
# Out:
#        Price_product3  Price_product1  Price_product2  Price_product4
# count      101.000000      101.000000      101.000000      101.000000
# mean       110.590879       62.371903      104.746805      134.692887
# std          5.877259        2.504866        5.018190        5.103280
# min         92.926829       59.968750       99.924528      124.666667
# 25%        105.506329       60.000000      100.000000      130.000000
# 50%        108.275862       60.000000      100.000000      130.000000
# 75%        115.722543       65.000000      110.000000      140.000000
# max        124.318182       65.000000      110.000000      140.000000

# %%
X = multi.iloc[:,1:5]

# %%
X = sm.add_constant(X)

# %%
X
# Out:
#      const  Price_product3  Price_product1  Price_product2  Price_product4
# 0      1.0       92.926829       60.000000      100.000000      130.000000
# 1      1.0      117.118644       65.000000      110.000000      140.000000
# 2      1.0      103.302752       60.000000      100.000000      130.000000
# 3      1.0      115.769231       65.000000      110.000000      140.000000
# 4      1.0      106.769231       60.054496      100.000000      129.727273
# ..     ...             ...             ...             ...             ...
# 96     1.0      107.435897       60.000000      100.000000      130.000000
# 97     1.0      102.788462       60.000000       99.959839      130.000000
# 98     1.0      103.431373       60.000000      100.000000      130.000000
# 99     1.0      107.813505       60.000000      100.000000      130.000000
# 100    1.0      108.603352       60.000000      100.000000      130.000000
#
# [101 rows x 5 columns]

# %%
multi.columns
# Out:
# Index(['week', 'Price_product3', 'Price_product1', 'Price_product2',
#        'Price_product4', 'sales_product3', 'sales_product1', 'sales_product2',
#        'sales_product4'],
#       dtype='object')

# %%
model_product_1 = sm.OLS(multi[['sales_product1']],X).fit()

# %%
model_product_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         sales_product1   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     1.631
# Date:                Sun, 08 Aug 2021   Prob (F-statistic):              0.173
# Time:                        20:27:18   Log-Likelihood:                -749.74
# No. Observations:                 101   AIC:                             1509.
# Df Residuals:                      96   BIC:                             1523.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
model_product_2 = sm.OLS(multi[['sales_product2']],X).fit()
model_product_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         sales_product2   R-squared:                       0.121
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     3.304
# Date:                Sun, 08 Aug 2021   Prob (F-statistic):             0.0139
# Time:                        20:31:07   Log-Likelihood:                -727.98
# No. Observations:                 101   AIC:                             1466.
# Df Residuals:                      96   BIC:                             1479.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
model_product_3 = sm.OLS(multi[['sales_product3']],X).fit()

# %%
model_product_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         sales_product3   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     2.098
# Date:                Sun, 08 Aug 2021   Prob (F-statistic):             0.0870
# Time:                        20:32:34   Log-Likelihood:                -647.37
# No. Observations:                 101   AIC:                             1305.
# Df Residuals:                      96   BIC:                             1318.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
model_product_4 = sm.OLS(multi[['sales_product4']], X).fit()
model_product_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         sales_product4   R-squared:                       0.132
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     3.662
# Date:                Sun, 08 Aug 2021   Prob (F-statistic):            0.00806
# Time:                        20:33:13   Log-Likelihood:                -589.86
# No. Observations:                 101   AIC:                             1190.
# Df Residuals:                      96   BIC:                             1203.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...
